# %%
import sqlite3
import pandas as pd

# %%
connection = sqlite3.connect('teste.db')
df = pd.read_sql_query("SELECT * FROM coins", connection)

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [coinID, coinName, coinValue, coinDate]
# Index: []
